# %%
#MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import LabelEncoder
data=[
    "free food",
      "claim your money",
      "win money",
      "welcome to company",
      "good morning",
      "hi bro"]
label=["spam","spam","spam","notspam","notspam","notspam"]
le=LabelEncoder()
y=le.fit_transform(label)
v=CountVectorizer()
x=vectorizer.fit_transform(data)
m= MultinomialNB()
m.fit(x,y)
tdata=["hi morming"]
test_vec = vectorizer.transform(tdata)
pre=m.predict(test_vec)
print("Prediction:", le.inverse_transform(pre)[0])
# Out:
# Prediction: notspam

# %%
#GaussianNB
import numpy as np
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
x = np.array([[1000],[2000],[3000],[8000],[10000],[20000],[25000],[30000]])
yt=["low","low","low","low","high","high","high","high"]
le= LabelEncoder()
y=le.fit_transform(yt)
model=GaussianNB()
model.fit(x, y)
newsal=[[9000]]
p=model.predict(newsal)
print("Pre:", le.inverse_transform(p)[0])
# Out:
# Pre: low

# %%
#BernoulliNB
import numpy as np
from sklearn.naive_bayes import BernoulliNB
from sklearn.preprocessing import LabelEncoder
x=np.array([
      [0.1],
    [1.0],
    [0.2],
    [2.0]
])
yt=["no","yes","no","yes"]
le=LabelEncoder()
y=le.fit_transform(yt)
model=BernoulliNB()
model.fit(x,y)
nd=[[0.1]]
pre=model.predict(nd)
print(le.inverse_transform(pre)[0])
# Out:
# no
