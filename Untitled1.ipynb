# %%
import matplotlib.pyplot as plt
from scipy.stats  import binom
n=15
p=0.1
k=2
prob=binom.pmf(k,n,p)
PMF=prob
print(PMF)
prob=binom.cdf(k,n,p)
CDF=prob
print(CDF)
# Out:
# 0.266895911974545
# 0.8159389308936089

# %%
import matplotlib.pyplot as plt
from scipy.stats import poisson as p
lam=5
k=3
pos=p.cdf(k,lam)
print("posprobability for 3person in one hour by chance cdf:",prob )
pos=p.pmf(k,lam)
print("posprobability for 3person in one hour correct chans in pmf:",prob )
# Out:
# posprobability for 3person in one hour by chance cdf: 0.8159389308936089
# posprobability for 3person in one hour correct chans in pmf: 0.8159389308936089

# %%
import matplotlib.pyplot as plt
from scipy.stats  import zscore as z
mean=50000
std=5000
x=40000
z=(x-mean)/std
z
# Out:
# -2.0

# %%
import matplotlib.pyplot as plt
from scipy.stats  import norm
mean=50000
std=5000
x=40000
prob=norm.cdf(mean,x,std)
print("cdf:",prob)
l=norm.pmf(mean,x,std)
pri
