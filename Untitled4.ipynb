# %%
from scipy.stats import expon
import numpy as np
import matplotlib.pyplot as plt
mean_time = 10  
t = 5  
lambda_value = 1 / mean_time
prob_within = expon.cdf(t, scale=1/lambda_value)
print(prob_within)
# Out:
# 0.3934693402873666

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
datax= np.array([
    [2005, 0], 
    [2008, 0], 
    [2018, 1],  
    [2022, 1]  
])
datay = np.array(["bs3andbs4", "bs3andbs4", "bs6", "bs6"])
model = KNeighborsClassifier(n_neighbors=3)
model.fit(datax, datay)
modelbk = [[2012, 0]]  
prediction = model.predict(modelbk)
print("modelofbk:", prediction[0])
# Out:
# modelofbk: bs3andbs4
